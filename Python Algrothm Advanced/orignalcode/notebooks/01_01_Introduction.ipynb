# %% [markdown]
# # Introduction
#
# ### 课程安排
# <img src="../images/ch01/syllabus.png" width="560"/>

# %% [markdown]
# ### 实例一：Find Missing Number
# You are given a list of n-1 integers and these integers are in the range of 1 to n. There are no duplicates in list. One of the integers is missing in the list. Write an efficient code to find the missing integer.
#
# ### 实例二：Tile Problem
# Given a 𝑛×2 board and tiles of size 1×2, count the number of ways to tile the given board using the 1×2 tiles. A tile can either be placed horizontally i.e., as a 1×2 tile or vertically i.e., as 2×1 tile.
#
# ### 实例三：Find Top k Most Searched Keywords from Amazon
#
# Amazon! How many records?
#
# Boss wants a quick answer
#
# How about in real time? Like every 5 mins

# %% [markdown]
# ### 算法分析
#
# #### 运行时间 （时间复杂度）
# - The running time typically grows with the input size
# - Best Case: Lower bound on cost
#     - Determine by “easiest” input
#     - Provides a goal for all inputs
# - Worse Case: Upper bound on cost
#     - Determine by “most difficult” input
#     - Provides a guarantee for all inputs
# - Average case: Expected cost for random input
#     - Need a model for “random” input
#     - Provides a way to predict performance
# - Average case time is often difficult to determine
# - We focus on worst case running time
#
# <img src="../images/ch01/algorithmmatters.png" width="580"/>

# %% [markdown]
# ##### Utility

# %%
import time
import matplotlib.pyplot as plt
import random as random
import math
# %matplotlib inline  

def random_list(l):
    return [[int(1000*random.random()) for i in range(l * n)] for n in range(1, 20)]

# %% [markdown]
# ** Large Scale **

# %%
from pylab import *

n = arange(1,100)
f1 = 1
f2 = n
f3 = n* (log(n))
f4 = n**2

fig = figure()
ax = fig.add_subplot(111)

ax.plot(f1)
ax.plot(f2)
ax.plot(f3)
ax.plot(f4)

legend(["1", "n", "nlgn", "n^2"], loc=2, fontsize="small")

title('Algorithm Matters') 

xlabel('Size of array (n)')
ylabel('Number of interations')

show()

# %% [markdown]
# ** Small Scale **

# %%
from pylab import *

n = arange(1,15)
f1 = 1
f2 = n
f3 = n* (log(n))
f4 = n**2
f5 = n**3
f6 = 2**n

fig = figure()
ax = fig.add_subplot(111)

ax.plot(f1)
ax.plot(f2)
ax.plot(f3)
ax.plot(f4)
ax.plot(f5)
ax.plot(f6)

legend(["1", "n", "nlgn", "n^2", "n^3", "2^n"], loc=2, fontsize="small")

title('Algorithm Matters') 

xlabel('Size of array (n)')
ylabel('Number of interations')

show()

# %% [markdown]
# ### $O(1)$  -  (constant)

# %%
def square(x):
    return x * x

square(3)
# Out:
# 9

# %%
def first(x): # x is a list
    start = time.time()
    r = x[0]
    t = time.time() - start
    return r, len(x), t

def middle(x):
    start = time.time()
    r = x[len(x)//2]
    t = time.time() - start
    return r, len(x), t

def last(x):
    start = time.time()
    r = x[-1]
    t = time.time() - start
    return r, len(x), t

# %%
random_lists = random_list(10000)
rst = [last(l) for l in random_lists]
len(rst)
rst
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-5bd0a534f7c5> in <module>
# ----> 1 random_lists = random_list(10000)
#       2 rst = [last(l) for l in random_lists]
#       3 len(rst)
#       4 rst
#
# <ipython-input-1-0cb4fd93a825> in random_list(l)
#       6
#       7 def random_list(l):
# ----> 8     return [[int(1000*random.random()) for i in range(l * n)] for n in range(1, 20)]
#
# <ipython-input-1-0cb4fd93a825> in <listcomp>(.0)
#       6
#       7 def random_list(l):
# ----> 8     return [[int(1000*random.random()) for i in range(l * n)] for n in range(1, 20)]
#
# <ipython-input-1-0cb4fd93a825> in <listcomp>(.0)
#       6
#       7 def random_list(l):
# ----> 8     return [[int(1000*random.random()) for i in range(l * n)] for n in range(1, 20)]
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'random'

# %%
x = list(zip(*rst))[1]
y = list(zip(*rst))[2]

plt.plot(x, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-92a752f3c133> in <module>
# ----> 1 x = list(zip(*rst))[1]
#       2 y = list(zip(*rst))[2]
#       3
#       4 plt.plot(x, y)
#
# NameError: name 'rst' is not defined

# %% [markdown]
# ### $O(lgn)$

# %%
import bisect
def bs(nums, target):
    sorted(nums)
    start = time.time()
    i = bisect.bisect_left(nums, target)
    if i != len(nums) and nums[i] == target:
        t = time.time() - start
        return i, len(nums), t
    t = time.time() - start
    return -1, len(nums), t

# %%
random_lists = random_list(10000)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-d7f7c213c0c1> in <module>
# ----> 1 random_lists = random_list(10000)
#
# <ipython-input-1-38bd7dbd915f> in random_list(l)
#       6
#       7 def random_list(l):
# ----> 8     return [[int(1000*random.random()) for i in range(l * n)] for n in range(1, 20)]
#
# <ipython-input-1-38bd7dbd915f> in <listcomp>(.0)
#       6
#       7 def random_list(l):
# ----> 8     return [[int(1000*random.random()) for i in range(l * n)] for n in range(1, 20)]
#
# <ipython-input-1-38bd7dbd915f> in <listcomp>(.0)
#       6
#       7 def random_list(l):
# ----> 8     return [[int(1000*random.random()) for i in range(l * n)] for n in range(1, 20)]
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'random'

# %%
rst = [bs(l, 100) for l in random_lists]
len(rst)
rst
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-5ebc756135af> in <module>
# ----> 1 rst = [bs(l, 100) for l in random_lists]
#       2 len(rst)
#       3 rst
#
# NameError: name 'random_lists' is not defined

# %%
x = list(zip(*rst))[1]
y = list(zip(*rst))[2]

plt.plot(x, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-92a752f3c133> in <module>
# ----> 1 x = list(zip(*rst))[1]
#       2 y = list(zip(*rst))[2]
#       3
#       4 plt.plot(x, y)
#
# NameError: name 'rst' is not defined

# %% [markdown]
# ### $O(n)$

# %%
def find_max(l):
    start = time.time()
    
    if l == None:
        return None
    mx = l[0]
    for n in l:
        if n > mx:
            mx = n
            
    t = time.time() - start
    
    return mx, len(l), t

# %%
random_lists = random_list(20000)
rst = [find_max(l) for l in random_lists]
len(rst)
rst
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-04e3b7334719> in <module>
# ----> 1 random_lists = random_list(20000)
#       2 rst = [find_max(l) for l in random_lists]
#       3 len(rst)
#       4 rst
#
# <ipython-input-1-38bd7dbd915f> in random_list(l)
#       6
#       7 def random_list(l):
# ----> 8     return [[int(1000*random.random()) for i in range(l * n)] for n in range(1, 20)]
#
# <ipython-input-1-38bd7dbd915f> in <listcomp>(.0)
#       6
#       7 def random_list(l):
# ----> 8     return [[int(1000*random.random()) for i in range(l * n)] for n in range(1, 20)]
#
# <ipython-input-1-38bd7dbd915f> in <listcomp>(.0)
#       6
#       7 def random_list(l):
# ----> 8     return [[int(1000*random.random()) for i in range(l * n)] for n in range(1, 20)]
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'random'

# %%
x = list(zip(*rst))[1]
y = list(zip(*rst))[2]

plt.plot(x, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-92a752f3c133> in <module>
# ----> 1 x = list(zip(*rst))[1]
#       2 y = list(zip(*rst))[2]
#       3
#       4 plt.plot(x, y)
#
# NameError: name 'rst' is not defined

# %% [markdown]
# ### $O(nlgn)$

# %%
def mysort(l):
    start = time.time()
    l.sort()
    t = time.time() - start
    return l[0], len(l), t

# %%
random_lists = random_list(10000)
rst = [mysort(l) for l in random_lists]
len(rst)
rst
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-8ddf0ff9dafe> in <module>
# ----> 1 random_lists = random_list(10000)
#       2 rst = [mysort(l) for l in random_lists]
#       3 len(rst)
#       4 rst
#
# <ipython-input-1-38bd7dbd915f> in random_list(l)
#       6
#       7 def random_list(l):
# ----> 8     return [[int(1000*random.random()) for i in range(l * n)] for n in range(1, 20)]
#
# <ipython-input-1-38bd7dbd915f> in <listcomp>(.0)
#       6
#       7 def random_list(l):
# ----> 8     return [[int(1000*random.random()) for i in range(l * n)] for n in range(1, 20)]
#
# <ipython-input-1-38bd7dbd915f> in <listcomp>(.0)
#       6
#       7 def random_list(l):
# ----> 8     return [[int(1000*random.random()) for i in range(l * n)] for n in range(1, 20)]
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'random'

# %%
x = list(zip(*rst))[1]
y = list(zip(*rst))[2]

plt.plot(x, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-92a752f3c133> in <module>
# ----> 1 x = list(zip(*rst))[1]
#       2 y = list(zip(*rst))[2]
#       3
#       4 plt.plot(x, y)
#
# NameError: name 'rst' is not defined

# %% [markdown]
# ### $O(n^2)$

# %%
def has_duplicate(l):
    start = time.time()
    
    rst = False
    for i in range(len(l)):
        for j in range(i + 1, len(l)):
            if l[i] == l[j]:
                rst = True
        
    t = time.time() - start
    
    return rst, len(l), t

# %%
random_lists = random_list(100)
rst = [has_duplicate(l) for l in random_lists]

x = list(zip(*rst))[1]
y = list(zip(*rst))[2]

plt.plot(x, y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-3563958b86ea> in <module>
# ----> 1 random_lists = random_list(100)
#       2 rst = [has_duplicate(l) for l in random_lists]
#       3
#       4 x = list(zip(*rst))[1]
#       5 y = list(zip(*rst))[2]
#
# <ipython-input-1-38bd7dbd915f> in random_list(l)
#       6
#       7 def random_list(l):
# ----> 8     return [[int(1000*random.random()) for i in range(l * n)] for n in range(1, 20)]
#
# <ipython-input-1-38bd7dbd915f> in <listcomp>(.0)
#       6
#       7 def random_list(l):
# ----> 8     return [[int(1000*random.random()) for i in range(l * n)] for n in range(1, 20)]
#
# <ipython-input-1-38bd7dbd915f> in <listcomp>(.0)
#       6
#       7 def random_list(l):
# ----> 8     return [[int(1000*random.random()) for i in range(l * n)] for n in range(1, 20)]
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'random'
