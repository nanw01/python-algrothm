# %%
# Load Packages
import numpy as np
import pandas as pd
from pandas_datareader import data
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_theme()

# %%
data = pd.read_csv('./security_weights.csv')
data
# Out:
#       Unnamed: 0  ABC  AWK      AZO      CHTR  COO      COST       DVA   EW  \
# 0     2010-01-03  0.0  0.0  0.00000  0.000000  0.0  0.000000  0.000000  0.0
# 1     2010-01-04  0.0  0.0  0.00000  0.000000  0.0  0.000000  0.000000  0.0
# 2     2010-01-05  0.0  0.0  0.00000  0.000000  0.0  0.000000  0.000000  0.0
# 3     2010-01-06  0.0  0.0  0.00000  0.000000  0.0  0.000000  0.000000  0.0
# 4     2010-01-07  0.0  0.0  0.00000  0.000000  0.0  0.000000  0.000000  0.0
# ...          ...  ...  ...      ...       ...  ...       ...       ...  ...
# 2788  2021-01-29  0.0  0.0  0.07582  0.018348  0.0  0.037577  0.008246  0.0
# 2789  2021-02-01  0.0  0.0  0.00000  0.000000  0.0  0.000000  0.014409  0.0
# 2790  2021-02-02  0.0  0.0  0.00000  0.000000  0.0  0.000000  0.013652  0.0
# 2791  2021-02-03  0.0  0.0  0.00000  0.000000  0.0  0.000000  0.013549  0.0
# 2792  2021-02-04  0.0  0.0  0.00000  0.000000  0.0  0.000000  0.013583  0.0
#
# ...

# %%
data.plot()
# Out:
# <AxesSubplot:>
